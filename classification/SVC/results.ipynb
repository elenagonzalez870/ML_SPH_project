# %%
import joblib

# %%
# ----- Load training info -----
results = joblib.load('../best_models/svm_best_model.pkl')


print("Best Parameters:")
print(results['best_params'])
print("Test Accuracy ", results['test_accuracy']*100)
print("Test Balanced Accuracy ", results['test_balanced_accuracy']*100)
# Out:
# Best Parameters:
# {'C': 10000, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Test Accuracy  98.26839826839827
# Test Balanced Accuracy  97.71653109218673
